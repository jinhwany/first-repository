# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("~/data/data/bike-sharing-demand/train.csv")
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# 왜 복사 붙여넣기를 했는데 데이터가 안뜨나했는데, 파일경로가 달라서 안뜨는거였다. 그래서 새로 경로를 변경하니 원래대로 데이터가 떴다.

# %%
train['datetime'] = pd.to_datetime(train['datetime'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# 이 과정은 데이터를 더 보기 좋게 하기 위함인가?

# %%
train['year'] = pd.DatetimeIndex(train['datetime']).year
train['month'] = pd.DatetimeIndex(train['datetime']).month
train['day'] = pd.DatetimeIndex(train['datetime']).day
train['hour'] = pd.DatetimeIndex(train['datetime']).hour
train['minute'] = pd.DatetimeIndex(train['datetime']).minute
train['second'] = pd.DatetimeIndex(train['datetime']).second

# %%
출처 : https://datascienceschool.net/01%20python/04.08%20%EC%8B%9C%EA%B3%84%EC%97%B4%20%EC%9E%90%EB%A3%8C%20%EB%8B%A4%EB%A3%A8%EA%B8%B0.html / 아 이게 시계열 자료 다루는 방법이구나..

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second
# 0       0       0
# 1       0       0
# ...

# %% [markdown]
# 아.. 위에서 코딩한 결과가 이렇게 자료로 보기 좋게 된거구나.

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,3,1)
sns.countplot(x='year', data=train)

plt.subplot(2,3,2)
sns.countplot(x='month', data=train)

plt.subplot(2,3,3)
sns.countplot(x='day', data=train)

plt.subplot(2,3,4)
sns.countplot(x='hour', data=train)

plt.subplot(2,3,5)
sns.countplot(x='minute', data=train)

plt.subplot(2,3,6)
sns.countplot(x='second', data=train)

plt.show()

# %% [markdown]
# 연별로, 월별로, 일별로, 시간별로 확인을 할 수 있다.

# %%
X = train[['season', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'year', 'month', 'day', 'hour',]].values
y = train[['count']].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %% [markdown]
# 예전에 random_state=1 로 진행했는데 여기서는 2로 정해놓았네, 굳이 2로 할 필요가 있었나? 그리고 20% 80%는 약간 고정값인가? 더 좋은 비율은 없는건가..?

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[-33.96697339],
#        [ 59.23679918],
#        [112.62548605],
#        ...,
#        [195.79183719],
#        [197.74006566],
#        [294.24680107]])

# %%
rmse = mean_squared_error(y_test, predictions, squared = False)
rmse
# Out:
# 140.47528542723475

# %% [markdown]
# 출처 : https://jysden.medium.com/%EC%96%B8%EC%A0%9C-mse-mae-rmse%EB%A5%BC-%EC%82%AC%EC%9A%A9%ED%95%98%EB%8A%94%EA%B0%80-c473bd831c62
#
# 사실 rmse 가 중요한건 알겠는데, 아직도 정확하게 식을 구현하거나 설명이 쉽지 않다.

# %%
col = ['season', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'year', 'month', 'day', 'hour']
X_test_df = pd.DataFrame(X_test, columns=col)
X_test_df['predictions'] = predictions
X_test_df['y_test'] = y_test

# %%
X_test_df
# Out:
#       season  workingday  weather   temp   atemp  humidity  windspeed    year  \
# 0        1.0         1.0      2.0   6.56   9.090      80.0     8.9981  2011.0
# 1        2.0         1.0      2.0  14.76  16.665      71.0    19.0012  2011.0
# 2        3.0         1.0      3.0  24.60  27.275      88.0     8.9981  2011.0
# 3        2.0         1.0      1.0  16.40  20.455      56.0    23.9994  2011.0
# 4        4.0         1.0      2.0  22.14  25.760      49.0     8.9981  2012.0
# ...      ...         ...      ...    ...     ...       ...        ...     ...
# 2173     1.0         1.0      1.0  12.30  13.635      61.0    19.9995  2012.0
# 2174     1.0         1.0      1.0  28.70  31.820      39.0    16.9979  2012.0
# 2175     2.0         1.0      1.0  18.86  22.725      72.0    15.0013  2011.0
# 2176     1.0         1.0      1.0  12.30  13.635      42.0    31.0009  2012.0
# 2177     3.0         1.0      1.0  26.24  30.305      65.0    16.9979  2011.0
#
# ...

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.lineplot(x=X_test_df['temp'], y=X_test_df['predictions'])

plt.subplot(2,2,2)
sns.lineplot(x=X_test_df['temp'], y=X_test_df['y_test'])

plt.subplot(2,2,3)
sns.lineplot(x=X_test_df['humidity'], y=X_test_df['predictions'])

plt.subplot(2,2,4)
sns.lineplot(x=X_test_df['humidity'], y=X_test_df['y_test'])

plt.show()

# %% [markdown]
# 이 부분으로 온도와 습기에 대한 상관관계를 나타낼 수 있는건가?

# %% [markdown]
# 출처https://github.com/JaeHeee/AIFFEL_Project/blob/master/EXPLORATION/EXPLORATION%205.%20%EB%82%A0%EC%94%A8%20%EC%A2%8B%EC%9D%80%20%EC%9B%94%EC%9A%94%EC%9D%BC%20%EC%98%A4%ED%9B%84%20%EC%84%B8%20%EC%8B%9C%2C%20%EC%9E%90%EC%A0%84%EA%B1%B0%20%ED%83%80%EB%8A%94%20%EC%82%AC%EB%9E%8C%EC%9D%80%20%EB%AA%87%20%EB%AA%85%3F.ipynb

# %% [markdown]
# 솔직히 꺾이지 않는 마음으로 10년동안 한길을 걸어 왔듯이, 이 과정도 6개월동안 끝까지 하면 할 수 있을지 걱정이 되긴하다. 이렇게 코딩은 아예 못하고 하나씩 이해하려고 하지만, 이게 쌓여서 결국 내꺼가 될지 모르겠다. 시간이 빠듯하니 기초부터 하나씩 따라잡아야 될거같다고 느낀다. 이런식으로 가다가는 수박 겉핥기 그 이상 이하도 안될거 같다.
